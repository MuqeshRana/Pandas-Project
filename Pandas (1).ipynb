# %% [markdown]
# # Pandas Series

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
list = [1,2,3,-4,6,"DataValues"]

# %%
list
# Out:
# [1, 2, 3, -4, 6, 'DataValues']

# %%
series1=pd.Series(list)

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.Series([1,2,3,5,8])

# %%
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    8
# dtype: int64

# %%
#Creating Empty Series
empty_s = pd.Series([])
# Out:
# <ipython-input-9-74e5f73d5d4b>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_s = pd.Series([])

# %%
empty_s
# Out:
# Series([], dtype: float64)

# %%
empty_s
# Out:
# Series([], dtype: float64)

# %%
series2 = pd.Series([1,2,3,5,8], index = ['A', 'B', 'C', 'D', 'E'],
                    dtype=float, name="Data Value")

# %%
series2
# Out:
# A    1.0
# B    2.0
# C    3.0
# D    5.0
# E    8.0
# Name: Data Value, dtype: float64

# %%
pd.Series(0.5)
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s=pd.Series(0.5, index=['a','b','c'])

# %%
scaler_s
# Out:
# a    0.5
# b    0.5
# c    0.5
# dtype: float64

# %%
dict_s = pd.Series({'A':25,'B':50, 'C':75})

# %%
dict_s
# Out:
# A    25
# B    50
# C    75
# dtype: int64

# %%
s4 = pd.Series([9,8,7,6,5,4,3,2,1,0])

# %%
s4[4]
# Out:
# 5

# %%
s4[2]
# Out:
# 7

# %%
#For Slicing
s4[0:5]
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# dtype: int64

# %%
#For Slicing
s4[:5]
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# dtype: int64

# %%
#To find Maximum values 
max(s4)
# Out:
# 9

# %%
#To find minimum values 
min(s4)
# Out:
# 0

# %%
#TO aplly a condition on Value
s4[s4>5]
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# dtype: int64

# %%
s5=pd.Series([1,2,3,4,5,6,7,8,9,0])

# %%
s4+s5
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# 9     0
# dtype: int64

# %%
s6=pd.Series([1,2,7,8,9,0])

# %%
s6+s5
# Out:
# 0     2.0
# 1     4.0
# 2    10.0
# 3    12.0
# 4    14.0
# 5     6.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# dtype: float64

# %%
s5+s6
# Out:
# 0     2.0
# 1     4.0
# 2    10.0
# 3    12.0
# 4    14.0
# 5     6.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# dtype: float64

# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd

# %%
empty_df = pd.DataFrame()

# %%
empty_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['A','B', 'C', 'D']
lst
# Out:
# ['A', 'B', 'C', 'D']

# %%
df1 = pd.DataFrame(lst)
df1
# Out:
#    0
# 0  A
# 1  B
# 2  C
# 3  D

# %%
lst_on_lst = [["a",'b','c'],['d','e','f']]
lst_on_lst
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
df2 = pd.DataFrame(lst_on_lst)
df2
# Out:
#    0  1  2
# 0  a  b  c
# 1  d  e  f

# %%
dicts = {"Name":["Mk","Pk",'Gk','ok'], 'Marks':[9,5,7,6]}
dicts
# Out:
# {'Name': ['Mk', 'Pk', 'Gk', 'ok'], 'Marks': [9, 5, 7, 6]}

# %%
df3=pd.DataFrame(dicts)
df3
# Out:
#   Name  Marks
# 0   Mk      9
# 1   Pk      5
# 2   Gk      7
# 3   ok      6

# %%
#List of Dictionary
list_dict1 = [{'a':1, 'b':2},{'a':3,'b':4}]
list_dict1
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4}]

# %%
pd.DataFrame(list_dict1)
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
list_dict2 = [{'a':1, 'b':2},{'a':3,'b':4,'c':5}]
list_dict2
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4, 'c': 5}]

# %%
pd.DataFrame(list_dict2)
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
#List of Dictionary
list_dict3 = [{'a':1, 'b':2},{'A':3,'B':4}]
list_dict3
# Out:
# [{'a': 1, 'b': 2}, {'A': 3, 'B': 4}]

# %%
pd.DataFrame(list_dict3)
# Out:
#      a    b    A    B
# 0  1.0  2.0  NaN  NaN
# 1  NaN  NaN  3.0  4.0

# %%
#Dictionary of Series
dict_sr = {'ID': pd.Series([1,2,3]), 'Age': pd.Series([11,22,33])}
pd.DataFrame(dict_sr)
# Out:
#    ID  Age
# 0   1   11
# 1   2   22
# 2   3   33

# %% [markdown]
# # Reading CSV File in Pandas

# %%
import pandas as pd

# %%
pd.read_csv("C:\\Users\\shubh\\Downloads\\Top-10-IT-Companies-in-India.csv")
# Out:
#   Top 10 IT Companies in India
# 0                          TCS
# 1                      Infosys
# 2                Tech Mahindra
# 3                        Wipro
# 4             HCL Technologies
# 5                 L&T Infotech
# 6                     Mindtree
# 7                      Mphasis
# 8    Oracle Financial Services
# 9                  Rotla India

# %%
# TO know where is your data get stored in your System
import os
os.getcwd()
# Out:
# 'C:\\Users\\shubh\\PycharmProjects\\Data_Science\\venv\\Lib\\site-packages'

# %% [markdown]
# # How to write on CSV File in Pandas

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv")
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Industry', 'Inception', 'Revenue', 'Expenses', 'Profit',
#        'Growth'],
#       dtype='object')

# %%
df1 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",nrows=2)
df1
# Out:
#    ID       Name            Industry  Inception       Revenue  \
# 0   1    Lamtone         IT Services       2009  $11,757,018
# 1   2  Stripfind  Financial Services       2010  $12,329,371
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%

# %%
df2 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", usecols=[1,3])
df2
# Out:
#               Name  Inception
# 0          Lamtone       2009
# 1        Stripfind       2010
# 2  Canecorporation       2012
# 3         Mattouch       2013
# 4        Techdrill       2009
# 5         Techline       2006
# 6          Cityace       2010
# 7   Kayelectronics       2009
# 8          Ganzlax       2011
# 9      Trantraxlax       2011

# %%
df3 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", usecols=[2,4,7])
df3
# Out:
#               Industry       Revenue Growth
# 0          IT Services  $11,757,018     30%
# 1   Financial Services  $12,329,371     20%
# 2               Health  $10,597,009      7%
# 3          IT Services  $14,026,934     26%
# 4               Health  $10,573,990      8%
# 5               Health  $13,898,119     23%
# 6               Health   $9,254,614      6%
# 7               Health   $9,451,943      4%
# 8          IT Services  $14,001,180     18%
# 9  Government Services  $11,088,336      7%

# %%
df4 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", skiprows=1)
df4
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
df5 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", skiprows=[2,5])
df5
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   3  Canecorporation               Health       2012  $10,597,009
# 2   4         Mattouch          IT Services       2013  $14,026,934
# 3   6         Techline               Health       2006  $13,898,119
# 4   7          Cityace               Health       2010   $9,254,614
# 5   8   Kayelectronics               Health       2009   $9,451,943
# 6   9          Ganzlax          IT Services       2011  $14,001,180
# 7  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  7,591,189 Dollars   3005820     7%
# 2  7,429,377 Dollars   6597557    26%
# 3  5,470,303 Dollars   8427816    23%
# 4  6,249,498 Dollars   3005116     6%
# 5  3,878,113 Dollars   5573830     4%
# 6                NaN  11901180    18%
# 7  5,635,276 Dollars   5453060     7%

# %%
df6 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", index_col='ID')
df6
# Out:
#                Name             Industry  Inception       Revenue  \
# ID
# 1           Lamtone          IT Services       2009  $11,757,018
# 2         Stripfind   Financial Services       2010  $12,329,371
# 3   Canecorporation               Health       2012  $10,597,009
# 4          Mattouch          IT Services       2013  $14,026,934
# 5         Techdrill               Health       2009  $10,573,990
# 6          Techline               Health       2006  $13,898,119
# 7           Cityace               Health       2010   $9,254,614
# 8    Kayelectronics               Health       2009   $9,451,943
# 9           Ganzlax          IT Services       2011  $14,001,180
# 10      Trantraxlax  Government Services       2011  $11,088,336
#
#              Expenses    Profit Growth
# ID
# 1   6,482,465 Dollars   5274553    30%
# 2     916,455 Dollars  11412916    20%
# 3   7,591,189 Dollars   3005820     7%
# 4   7,429,377 Dollars   6597557    26%
# 5   7,435,363 Dollars   3138627     8%
# ...

# %%
df7 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", index_col='Name')
df7
# Out:
#                  ID             Industry  Inception       Revenue  \
# Name
# Lamtone           1          IT Services       2009  $11,757,018
# Stripfind         2   Financial Services       2010  $12,329,371
# Canecorporation   3               Health       2012  $10,597,009
# Mattouch          4          IT Services       2013  $14,026,934
# Techdrill         5               Health       2009  $10,573,990
# Techline          6               Health       2006  $13,898,119
# Cityace           7               Health       2010   $9,254,614
# Kayelectronics    8               Health       2009   $9,451,943
# Ganzlax           9          IT Services       2011  $14,001,180
# Trantraxlax      10  Government Services       2011  $11,088,336
#
#                           Expenses    Profit Growth
# Name
# Lamtone          6,482,465 Dollars   5274553    30%
# Stripfind          916,455 Dollars  11412916    20%
# Canecorporation  7,591,189 Dollars   3005820     7%
# ...

# %%
df8 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", index_col=1)
df8
# Out:
#                  ID             Industry  Inception       Revenue  \
# Name
# Lamtone           1          IT Services       2009  $11,757,018
# Stripfind         2   Financial Services       2010  $12,329,371
# Canecorporation   3               Health       2012  $10,597,009
# Mattouch          4          IT Services       2013  $14,026,934
# Techdrill         5               Health       2009  $10,573,990
# Techline          6               Health       2006  $13,898,119
# Cityace           7               Health       2010   $9,254,614
# Kayelectronics    8               Health       2009   $9,451,943
# Ganzlax           9          IT Services       2011  $14,001,180
# Trantraxlax      10  Government Services       2011  $11,088,336
#
#                           Expenses    Profit Growth
# Name
# Lamtone          6,482,465 Dollars   5274553    30%
# Stripfind          916,455 Dollars  11412916    20%
# Canecorporation  7,591,189 Dollars   3005820     7%
# ...

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df9 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", header = None )
df9
# Out:
#      0                1                    2          3             4  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     5         6       7
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %%
df10 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", header = 3 )
df10
# Out:
#     3 Canecorporation               Health  2012  $10,597,009   \
# 0   4        Mattouch          IT Services  2013  $14,026,934
# 1   5       Techdrill               Health  2009  $10,573,990
# 2   6        Techline               Health  2006  $13,898,119
# 3   7         Cityace               Health  2010   $9,254,614
# 4   8  Kayelectronics               Health  2009   $9,451,943
# 5   9         Ganzlax          IT Services  2011  $14,001,180
# 6  10     Trantraxlax  Government Services  2011  $11,088,336
#
#    7,591,189 Dollars   3005820   7%
# 0  7,429,377 Dollars   6597557  26%
# 1  7,435,363 Dollars   3138627   8%
# 2  5,470,303 Dollars   8427816  23%
# 3  6,249,498 Dollars   3005116   6%
# 4  3,878,113 Dollars   5573830   4%
# 5                NaN  11901180  18%
# 6  5,635,276 Dollars   5453060   7%

# %%
df11 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", header=None,
                  prefix = 'Columns')
df11
# Out:
#    Columns0         Columns1             Columns2   Columns3      Columns4  \
# 0        ID             Name             Industry  Inception       Revenue
# 1         1          Lamtone          IT Services       2009  $11,757,018
# 2         2        Stripfind   Financial Services       2010  $12,329,371
# 3         3  Canecorporation               Health       2012  $10,597,009
# 4         4         Mattouch          IT Services       2013  $14,026,934
# 5         5        Techdrill               Health       2009  $10,573,990
# 6         6         Techline               Health       2006  $13,898,119
# 7         7          Cityace               Health       2010   $9,254,614
# 8         8   Kayelectronics               Health       2009   $9,451,943
# 9         9          Ganzlax          IT Services       2011  $14,001,180
# 10       10      Trantraxlax  Government Services       2011  $11,088,336
#
#              Columns5  Columns6 Columns7
# ...

# %%
df12 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", header=None,
                  prefix = 'Muqesh')
df12
# Out:
#    Muqesh0          Muqesh1              Muqesh2    Muqesh3       Muqesh4  \
# 0       ID             Name             Industry  Inception       Revenue
# 1        1          Lamtone          IT Services       2009  $11,757,018
# 2        2        Stripfind   Financial Services       2010  $12,329,371
# 3        3  Canecorporation               Health       2012  $10,597,009
# 4        4         Mattouch          IT Services       2013  $14,026,934
# 5        5        Techdrill               Health       2009  $10,573,990
# 6        6         Techline               Health       2006  $13,898,119
# 7        7          Cityace               Health       2010   $9,254,614
# 8        8   Kayelectronics               Health       2009   $9,451,943
# 9        9          Ganzlax          IT Services       2011  $14,001,180
# 10      10      Trantraxlax  Government Services       2011  $11,088,336
#
#               Muqesh5   Muqesh6 Muqesh7
# 0            Expenses    Profit  Growth
# ...

# %%
df13 = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", 
                  names=['Ag','Bg','Cd','Dj','Eo','Fo'])
df13
# Out:
#                                      Ag         Bg            Cd  \
# ID Name                        Industry  Inception       Revenue
# 1  Lamtone                  IT Services       2009  $11,757,018
# 2  Stripfind         Financial Services       2010  $12,329,371
# 3  Canecorporation               Health       2012  $10,597,009
# 4  Mattouch                 IT Services       2013  $14,026,934
# 5  Techdrill                     Health       2009  $10,573,990
# 6  Techline                      Health       2006  $13,898,119
# 7  Cityace                       Health       2010   $9,254,614
# 8  Kayelectronics                Health       2009   $9,451,943
# 9  Ganzlax                  IT Services       2011  $14,001,180
# 10 Trantraxlax      Government Services       2011  $11,088,336
#
#                                    Dj        Eo      Fo
# ID Name                      Expenses    Profit  Growth
# 1  Lamtone          6,482,465 Dollars   5274553     30%
# ...

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.head(1)
# Out:
#    ID     Name     Industry  Inception       Revenue           Expenses  \
# 0   1  Lamtone  IT Services       2009  $11,757,018   6,482,465 Dollars
#
#     Profit Growth
# 0  5274553    30%

# %%
df.tail(4)
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 6   7         Cityace               Health       2010   $9,254,614
# 7   8  Kayelectronics               Health       2009   $9,451,943
# 8   9         Ganzlax          IT Services       2011  $14,001,180
# 9  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", 
                 dtype = {'ID':'float64'} )
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", 
                 dtype = {'ID':'float64', 'Profit':'float'} )
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   3005820.0     7%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", 
                 true_values=['Yes'], false_values=['No'])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# # Handling Missing Value in Pandas

# %%
import pandas

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_9.csv")
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv")
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", na_values=['Mattouch','Health'])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation                  NaN       2012  $10,597,009
# 3   4              NaN          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv", na_values=['7%','26%''Mattouch','Health'])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation                  NaN       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820    NaN
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",
                 na_values=['7%','26%''Mattouch','Health'])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation                  NaN       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820    NaN
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",
                 na_values={'Industry':'no values'})
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",
                 keep_default_na=False)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",
                 keep_default_na=True)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv",
                 na_filter=False)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False   False
# 4  False  False     False      False    False     False   False   False
# 5  False  False     False      False    False     False   False   False
# 6  False  False     False      False    False     False   False   False
# 7  False  False     False      False    False     False   False   False
# 8  False  False     False      False    False     False   False   False
# 9  False  False     False      False    False     False   False   False

# %%
df_null = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_9.csv")
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df_null.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False    True
# 4  False  False      True      False    False     False   False    True
# 5  False  False      True      False    False     False   False    True
# 6  False  False      True      False    False     False   False    True
# 7  False  False      True      False    False     False   False    True
# 8  False  False     False      False    False      True   False   False
# 9  False  False     False      False    False     False   False   False

# %%
# TO know how many Null Values is there
df_null.isnull().sum()
# Out:
# ID           0
# Name         0
# Industry     4
# Inception    0
# Revenue      0
# Expenses     1
# Profit       0
# Growth       5
# dtype: int64

# %%
# TO know how many Null Values is there
df_null.isnull().sum().sum()
# Out:
# 10

# %%
df_null = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_9.csv")
df_null.notnull()
# Out:
#      ID  Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True      True       True     True      True    True    True
# 1  True  True      True       True     True      True    True    True
# 2  True  True      True       True     True      True    True    True
# 3  True  True      True       True     True      True    True   False
# 4  True  True     False       True     True      True    True   False
# 5  True  True     False       True     True      True    True   False
# 6  True  True     False       True     True      True    True   False
# 7  True  True     False       True     True      True    True   False
# 8  True  True      True       True     True     False    True    True
# 9  True  True      True       True     True      True    True    True

# %%
df_null.notnull().sum()
# Out:
# ID           10
# Name         10
# Industry      6
# Inception    10
# Revenue      10
# Expenses      9
# Profit       10
# Growth        5
# dtype: int64

# %%
df_null.notnull().sum().sum()
# Out:
# 70

# %%
#Series
import numpy as np
sr=pd.Series([1,2,3,np.nan, 5,np.nan])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
df_null = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_9.csv")
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df_null.dropna()
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 9  5,635,276 Dollars   5453060     7%

# %%
df_null.dropna(axis=1)
# Out:
#    ID             Name  Inception       Revenue    Profit
# 0   1          Lamtone       2009  $11,757,018    5274553
# 1   2        Stripfind       2010  $12,329,371   11412916
# 2   3  Canecorporation       2012  $10,597,009    3005820
# 3   4         Mattouch       2013  $14,026,934    6597557
# 4   5        Techdrill       2009  $10,573,990    3138627
# 5   6         Techline       2006  $13,898,119    8427816
# 6   7          Cityace       2010   $9,254,614    3005116
# 7   8   Kayelectronics       2009   $9,451,943    5573830
# 8   9          Ganzlax       2011  $14,001,180   11901180
# 9  10      Trantraxlax       2011  $11,088,336    5453060

# %%
#Drops R/C only if all elements of any R/C is null
df_null.dropna(axis=1, how='all')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
#Drops R/C only if any elements of any R/C is null
df_null.dropna(axis=1, how='any')
# Out:
#    ID             Name  Inception       Revenue    Profit
# 0   1          Lamtone       2009  $11,757,018    5274553
# 1   2        Stripfind       2010  $12,329,371   11412916
# 2   3  Canecorporation       2012  $10,597,009    3005820
# 3   4         Mattouch       2013  $14,026,934    6597557
# 4   5        Techdrill       2009  $10,573,990    3138627
# 5   6         Techline       2006  $13,898,119    8427816
# 6   7          Cityace       2010   $9,254,614    3005116
# 7   8   Kayelectronics       2009   $9,451,943    5573830
# 8   9          Ganzlax       2011  $14,001,180   11901180
# 9  10      Trantraxlax       2011  $11,088,336    5453060

# %%
#Returns R/C if they have Atleast Thresold numbers of Not_Null Value
df_null.dropna(thresh=1)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
#Returns R/C if they have Atleast Thresold numbers of Not_Null Value
df_null.dropna(axis=1,thresh=5)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
# Returns if that perticiular R/C has Not_Null Value
df_null.dropna(subset=['Industry'])
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df_null.dropna()
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 9  5,635,276 Dollars   5453060     7%

# %%
#Updating File
df_null.dropna(inplace=True)
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 9  5,635,276 Dollars   5453060     7%

# %%
df_null = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_9.csv")
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df_null.fillna(2)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                    2       2009  $10,573,990
# 5   6         Techline                    2       2006  $13,898,119
# 6   7          Cityace                    2       2010   $9,254,614
# 7   8   Kayelectronics                    2       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557      2
# ...

# %%
df_null.fillna({'Industry':'Muqesh', 'Expenses':'100Rupees', 'Growth':'10%'})
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Muqesh       2009  $10,573,990
# 5   6         Techline               Muqesh       2006  $13,898,119
# 6   7          Cityace               Muqesh       2010   $9,254,614
# 7   8   Kayelectronics               Muqesh       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    10%
# ...

# %%
#Replacing NaN values with Previous value, ffill=forward fill
df_null.fillna(method='ffill')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     7%
# ...

# %%
#Replacing NaN values with Previous value,same as ffill
df_null.fillna(method='pad')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     7%
# ...

# %%
#Replacing NaN values with backward value, bfill=backward fill
df_null.fillna(method='bfill')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    18%
# ...

# %%
#Replacing NaN values with Previous column values
df_null.fillna(method='ffill', axis=1)
# Out:
#    ID             Name             Industry Inception       Revenue  \
# 0   1          Lamtone          IT Services      2009  $11,757,018
# 1   2        Stripfind               Health      2010  $12,329,371
# 2   3  Canecorporation               Health      2012  $10,597,009
# 3   4         Mattouch          IT Services      2013  $14,026,934
# 4   5        Techdrill            Techdrill      2009  $10,573,990
# 5   6         Techline             Techline      2006  $13,898,119
# 6   7          Cityace              Cityace      2010   $9,254,614
# 7   8   Kayelectronics       Kayelectronics      2009   $9,451,943
# 8   9          Ganzlax          IT Services      2011  $14,001,180
# 9  10      Trantraxlax  Government Services      2011  $11,088,336
#
#             Expenses    Profit   Growth
# 0  6,482,465 Dollars   5274553      30%
# 1    916,455 Dollars  11412916      20%
# 2  7,591,189 Dollars   3005820       7%
# 3  7,429,377 Dollars   6597557  6597557
# ...

# %%
#Replacing NaN values with Backward column values
df_null.fillna(method='bfill', axis=1)
# Out:
#    ID             Name             Industry Inception       Revenue  \
# 0   1          Lamtone          IT Services      2009  $11,757,018
# 1   2        Stripfind               Health      2010  $12,329,371
# 2   3  Canecorporation               Health      2012  $10,597,009
# 3   4         Mattouch          IT Services      2013  $14,026,934
# 4   5        Techdrill                 2009      2009  $10,573,990
# 5   6         Techline                 2006      2006  $13,898,119
# 6   7          Cityace                 2010      2010   $9,254,614
# 7   8   Kayelectronics                 2009      2009   $9,451,943
# 8   9          Ganzlax          IT Services      2011  $14,001,180
# 9  10      Trantraxlax  Government Services      2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
#Replacing NaN values with Previous values for limit of 2 elements
df_null.fillna(method='ffill', limit=2)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     7%
# ...

# %%
#Replacing NaN values with value 1 for limit of 3 elements
df_null.fillna(1, limit=3)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                    1       2009  $10,573,990
# 5   6         Techline                    1       2006  $13,898,119
# 6   7          Cityace                    1       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557      1
# ...

# %%
#Replacing NaN values with 51, and updating File
df_null.fillna(51, inplace=True)
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                   51       2009  $10,573,990
# 5   6         Techline                   51       2006  $13,898,119
# 6   7          Cityace                   51       2010   $9,254,614
# 7   8   Kayelectronics                   51       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     51
# ...

# %%
df_null
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind               Health       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                   51       2009  $10,573,990
# 5   6         Techline                   51       2006  $13,898,119
# 6   7          Cityace                   51       2010   $9,254,614
# 7   8   Kayelectronics                   51       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     51
# ...

# %% [markdown]
# # replace() of Pandas

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\Fortune_10.csv")
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace(to_replace='Health', value='Education')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation            Education       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill            Education       2009  $10,573,990
# 5   6         Techline            Education       2006  $13,898,119
# 6   7          Cityace            Education       2010   $9,254,614
# 7   8   Kayelectronics            Education       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace('Health', 'Education')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation            Education       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill            Education       2009  $10,573,990
# 5   6         Techline            Education       2006  $13,898,119
# 6   7          Cityace            Education       2010   $9,254,614
# 7   8   Kayelectronics            Education       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace(4,14)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3  14         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace([1,2,3,4],[11,22,33,44])
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0  11          Lamtone          IT Services       2009  $11,757,018
# 1  22        Stripfind   Financial Services       2010  $12,329,371
# 2  33  Canecorporation               Health       2012  $10,597,009
# 3  44         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace([1,2,3,4,5], 11)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0  11          Lamtone          IT Services       2009  $11,757,018
# 1  11        Stripfind   Financial Services       2010  $12,329,371
# 2  11  Canecorporation               Health       2012  $10,597,009
# 3  11         Mattouch          IT Services       2013  $14,026,934
# 4  11        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace({'Industry':'Health'}, 'Agriculture')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation          Agriculture       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          Agriculture       2009  $10,573,990
# 5   6         Techline          Agriculture       2006  $13,898,119
# 6   7          Cityace          Agriculture       2010   $9,254,614
# 7   8   Kayelectronics          Agriculture       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace({'ID':[1,2,3], 'Industry':'Health'}, 'Finance')
# Out:
#         ID             Name             Industry  Inception       Revenue  \
# 0  Finance          Lamtone          IT Services       2009  $11,757,018
# 1  Finance        Stripfind   Financial Services       2010  $12,329,371
# 2  Finance  Canecorporation              Finance       2012  $10,597,009
# 3        4         Mattouch          IT Services       2013  $14,026,934
# 4        5        Techdrill              Finance       2009  $10,573,990
# 5        6         Techline              Finance       2006  $13,898,119
# 6        7          Cityace              Finance       2010   $9,254,614
# 7        8   Kayelectronics              Finance       2009   $9,451,943
# 8        9          Ganzlax          IT Services       2011  $14,001,180
# 9       10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace('[A-Za-z]',0)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace('[A-Za-z]',0, regex=True)
# Out:
#    ID  Name  Industry  Inception       Revenue  Expenses    Profit Growth
# 0   1     0         0       2009  $11,757,018        0.0   5274553    30%
# 1   2     0         0       2010  $12,329,371        0.0  11412916    20%
# 2   3     0         0       2012  $10,597,009        0.0   3005820     7%
# 3   4     0         0       2013  $14,026,934        0.0   6597557    26%
# 4   5     0         0       2009  $10,573,990        0.0   3138627     8%
# 5   6     0         0       2006  $13,898,119        0.0   8427816    23%
# 6   7     0         0       2010   $9,254,614        0.0   3005116     6%
# 7   8     0         0       2009   $9,451,943        0.0   5573830     4%
# 8   9     0         0       2011  $14,001,180        NaN  11901180    18%
# 9  10     0         0       2011  $11,088,336        0.0   5453060     7%

# %%
df.replace('[A-Z]','X',regex=True)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Xamtone          XX Xervices       2009  $11,757,018
# 1   2        Xtripfind   Xinancial Xervices       2010  $12,329,371
# 2   3  Xanecorporation               Xealth       2012  $10,597,009
# 3   4         Xattouch          XX Xervices       2013  $14,026,934
# 4   5        Xechdrill               Xealth       2009  $10,573,990
# 5   6         Xechline               Xealth       2006  $13,898,119
# 6   7          Xityace               Xealth       2010   $9,254,614
# 7   8   Xayelectronics               Xealth       2009   $9,451,943
# 8   9          Xanzlax          XX Xervices       2011  $14,001,180
# 9  10      Xrantraxlax  Xovernment Xervices       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Xollars   5274553    30%
# 1    916,455 Xollars  11412916    20%
# 2  7,591,189 Xollars   3005820     7%
# 3  7,429,377 Xollars   6597557    26%
# ...

# %%
df.replace('a',5, regex=True)
# Out:
#    ID       Name             Industry  Inception       Revenue  Expenses  \
# 0   1          5          IT Services       2009  $11,757,018        5.0
# 1   2  Stripfind                    5       2010  $12,329,371        5.0
# 2   3          5                    5       2012  $10,597,009        5.0
# 3   4          5          IT Services       2013  $14,026,934        5.0
# 4   5  Techdrill                    5       2009  $10,573,990        5.0
# 5   6   Techline                    5       2006  $13,898,119        5.0
# 6   7          5                    5       2010   $9,254,614        5.0
# 7   8          5                    5       2009   $9,451,943        5.0
# 8   9          5          IT Services       2011  $14,001,180        NaN
# 9  10          5  Government Services       2011  $11,088,336        5.0
#
#      Profit Growth
# 0   5274553    30%
# 1  11412916    20%
# 2   3005820     7%
# 3   6597557    26%
# 4   3138627     8%
# 5   8427816    23%
# 6   3005116     6%
# ...

# %%
df.replace('Health',method='ffill')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation   Financial Services       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace('Health', method='bfill')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation          IT Services       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace('Health', method='bfill', limit=2)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation          IT Services       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.replace('Health', method='ffill', limit=2, inplace=True)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# # Pandas intrpolate() Function

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\shubh\\PycharmProjects\\Data_Science\\My_Students_Data.csv')
df
# Out:
#          Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  08-07-2020        1001     10          2           9.0
# 1  09-07-2020        1002     10          6           8.0
# 2  10-07-2020        1003     10          3           8.0
# 3  11-07-2020        1004     11          0           NaN
# 4  12-07-2020        1005     11          4           NaN
# 5  13-07-2020        1006     11         10           NaN
# 6  14-07-2020        1007     12          4           NaN
# 7  15-07-2020        1008     12         10           6.0
# 8  16-07-2020        1009     12          2           8.0
# 9  17-07-2020        1010     12          6           9.0
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3               5.0        50.0
# 1                       2               0.0         NaN
# 2                       2               4.0         NaN
# 3                       1               5.0        45.0
# ...

# %%
# linearly Fills value Automatically 
df.interpolate()
# Out:
#          Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  08-07-2020        1001     10          2           9.0
# 1  09-07-2020        1002     10          6           8.0
# 2  10-07-2020        1003     10          3           8.0
# 3  11-07-2020        1004     11          0           7.6
# 4  12-07-2020        1005     11          4           7.2
# 5  13-07-2020        1006     11         10           6.8
# 6  14-07-2020        1007     12          4           6.4
# 7  15-07-2020        1008     12         10           6.0
# 8  16-07-2020        1009     12          2           8.0
# 9  17-07-2020        1010     12          6           9.0
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3          5.000000   50.000000
# 1                       2          0.000000   48.333333
# 2                       2          4.000000   46.666667
# 3                       1          5.000000   45.000000
# ...

# %%
# linearly Fills value Automatically 
df.interpolate(method='linear')
# Out:
#          Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  08-07-2020        1001     10          2           9.0
# 1  09-07-2020        1002     10          6           8.0
# 2  10-07-2020        1003     10          3           8.0
# 3  11-07-2020        1004     11          0           7.6
# 4  12-07-2020        1005     11          4           7.2
# 5  13-07-2020        1006     11         10           6.8
# 6  14-07-2020        1007     12          4           6.4
# 7  15-07-2020        1008     12         10           6.0
# 8  16-07-2020        1009     12          2           8.0
# 9  17-07-2020        1010     12          6           9.0
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3          5.000000   50.000000
# 1                       2          0.000000   48.333333
# 2                       2          4.000000   46.666667
# 3                       1          5.000000   45.000000
# ...

# %%
#To fill the value according to the Date-Time
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-821734478e59> in <module>
#       1 #To fill the value according to the Date-Time
# ----> 2 df.interpolate(method='time')
#
# ~\PycharmProjects\Data_Science\venv\Lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7005             )
#    7006         data = _maybe_transposed_self._data
# -> 7007         new_data = data.interpolate(
#    7008             method=method,
#    7009             axis=ax,
#
# ~\PycharmProjects\Data_Science\venv\Lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     568
#     569     def interpolate(self, **kwargs):
# --> 570         return self.apply("interpolate", **kwargs)
#     571
#     572     def shift(self, **kwargs):
#
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
'''
Changing the type of Date Column To make it in the format of
Pandas Date Format suitable for DateStamping
'''

df=pd.read_csv('C:\\Users\\shubh\\PycharmProjects\\Data_Science\\My_Students_Data.csv',
              parse_dates = ['Date'])
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0 2020-08-07        1001     10          2           9.0
# 1 2020-09-07        1002     10          6           8.0
# 2 2020-10-07        1003     10          3           8.0
# 3 2020-11-07        1004     11          0           NaN
# 4 2020-12-07        1005     11          4           NaN
# 5 2020-07-13        1006     11         10           NaN
# 6 2020-07-14        1007     12          4           NaN
# 7 2020-07-15        1008     12         10           6.0
# 8 2020-07-16        1009     12          2           8.0
# 9 2020-07-17        1010     12          6           9.0
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3               5.0        50.0
# 1                       2               0.0         NaN
# 2                       2               4.0         NaN
# 3                       1               5.0        45.0
# ...

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df=pd.read_csv('C:\\Users\\shubh\\PycharmProjects\\Data_Science\\My_Students_Data.csv',
              parse_dates=['Date'], index_col='Date')
df
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           NaN
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0        50.0
# 2020-09-07                       2               0.0         NaN
# 2020-10-07                       2               4.0         NaN
# 2020-11-07                       1               5.0        45.0
# ...

# %%
#To fill the empty cell according to Date/Time
df.interpolate(method='time')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           8.0
# 2020-12-07        1005     11          4           8.0
# 2020-07-13        1006     11         10           6.0
# 2020-07-14        1007     12          4           6.0
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0   50.000000
# 2020-09-07                       2               0.0   48.315217
# 2020-10-07                       2               4.0   46.684783
# 2020-11-07                       1               5.0   45.000000
# ...

# %%
#Filling According to index value which is Date here
df.interpolate(method='index')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           8.0
# 2020-12-07        1005     11          4           8.0
# 2020-07-13        1006     11         10           6.0
# 2020-07-14        1007     12          4           6.0
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0   50.000000
# 2020-09-07                       2               0.0   48.315217
# 2020-10-07                       2               4.0   46.684783
# 2020-11-07                       1               5.0   45.000000
# ...

# %%
#Fills According to Nearest Value
import scipy
df.interpolate(method='nearest')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           NaN
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0        50.0
# 2020-09-07                       2               0.0        50.0
# 2020-10-07                       2               4.0        45.0
# 2020-11-07                       1               5.0        45.0
# ...

# %%
df.interpolate(method='polynomial', order=2)
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           NaN
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0   50.000000
# 2020-09-07                       2               0.0 -132.397899
# 2020-10-07                       2               4.0  -40.988301
# 2020-11-07                       1               5.0   45.000000
# ...

# %%
df.interpolate(method='slinear', order=2)
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           NaN
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0   50.000000
# 2020-09-07                       2               0.0   48.315217
# 2020-10-07                       2               4.0   46.684783
# 2020-11-07                       1               5.0   45.000000
# ...

# %%
df.interpolate(limit=1, limit_direction='backward')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           6.4
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3          5.000000   50.000000
# 2020-09-07                       2          0.000000         NaN
# 2020-10-07                       2          4.000000   46.666667
# 2020-11-07                       1          5.000000   45.000000
# ...

# %%
df.interpolate(limit_area='inside')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           7.6
# 2020-12-07        1005     11          4           7.2
# 2020-07-13        1006     11         10           6.8
# 2020-07-14        1007     12          4           6.4
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3          5.000000   50.000000
# 2020-09-07                       2          0.000000   48.333333
# 2020-10-07                       2          4.000000   46.666667
# 2020-11-07                       1          5.000000   45.000000
# ...

# %%
df.interpolate(limit_area='outside')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           NaN
# 2020-12-07        1005     11          4           NaN
# 2020-07-13        1006     11         10           NaN
# 2020-07-14        1007     12          4           NaN
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3               5.0        50.0
# 2020-09-07                       2               0.0         NaN
# 2020-10-07                       2               4.0         NaN
# 2020-11-07                       1               5.0        45.0
# ...

# %%
df.interpolate(inplace=True)
df
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2020-08-07        1001     10          2           9.0
# 2020-09-07        1002     10          6           8.0
# 2020-10-07        1003     10          3           8.0
# 2020-11-07        1004     11          0           7.6
# 2020-12-07        1005     11          4           7.2
# 2020-07-13        1006     11         10           6.8
# 2020-07-14        1007     12          4           6.4
# 2020-07-15        1008     12         10           6.0
# 2020-07-16        1009     12          2           8.0
# 2020-07-17        1010     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2020-08-07                       3          5.000000   50.000000
# 2020-09-07                       2          0.000000   48.333333
# 2020-10-07                       2          4.000000   46.666667
# 2020-11-07                       1          5.000000   45.000000
# ...

# %% [markdown]
# # Pandas iLOC and LOC
